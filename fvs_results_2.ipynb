# %%
import pandas as pd
import sqlite3
import sqlalchemy 
import os
import matplotlib.pyplot as plt

# %%
try:
    conn = sqlite3.connect("FVS_Outputs2.db")    
except Exception as e:
    print(e)

#Now in order to read in pandas dataframe we need to know table name
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(f"Table Name : {cursor.fetchall()}")


cases = pd.read_sql_query('SELECT * FROM FVS_Cases', conn)
carbon = pd.read_sql_query('SELECT * FROM FVS_Carbon', conn)
fuels = pd.read_sql_query('SELECT * FROM FVS_Fuels', conn)
summary = pd.read_sql_query('SELECT * FROM FVS_Summary2_East', conn)
FVS_Hrv_Carbon = pd.read_sql_query('SELECT * FROM FVS_Hrv_Carbon', conn)

conn.close()
# Out:
# Table Name : [('FVS_Cases',), ('FVS_Fuels',), ('FVS_Carbon',), ('FVS_Hrv_Carbon',), ('FVS_Summary2_East',)]

# %%
cases
# Out:
#                                   CaseID    Stand_CN     StandID MgmtID  \
# 0   4592a17b-6b16-477e-bd9d-5fd8702f29be     Base_HL     Base_HL   test
# 1   3495ae84-1c07-478c-858a-28a793c6358d     Base_BK     Base_BK   test
# 2   1bab039c-566a-480e-a73d-520087a77e54  Base_BK-WN  Base_BK-WN   test
# 3   e93699e1-572c-4a40-912f-4d2dd616c0b9     Base_AB     Base_AB   test
# 4   3f3daf0a-fdc6-41f7-80a6-4f6a804713c5     Base_LP     Base_LP   test
# 5   b71a1485-af0c-4f8c-959f-31d621523c70     Base_RO     Base_RO   test
# 6   21c9508c-4cd2-4047-a2e7-ef1417050d36     Base_WN     Base_WN   test
# 7   16af14d8-68b7-4226-a577-cc7baa392ab7       HD_HL       HD_HL   test
# 8   44c9ee94-62a9-43f7-8cb8-38be262ef8c4       HD_BK       HD_BK   test
# 9   89b5f3cc-096f-4c5b-92ec-b7a696522f04    HD_BK-WN    HD_BK-WN   test
# 10  4db9d288-5946-420c-8036-d72848a7c91e       HD_AB       HD_AB   test
# 11  514728a6-6268-4427-ba10-49866cf17474       HD_LP       HD_LP   test
# 12  3721eff8-c862-41a8-a278-ba7e789c4a5f       HD_RO       HD_RO   test
# 13  386a96cc-615d-4f90-a054-cdc3e46f1378       HD_WN       HD_WN   test
# 14  512b0ab7-6035-4acc-b6a9-5264a964fa03     HI_VAR1     HI_VAR1   test
# 15  eef5ee0d-f290-4aa9-934f-578106268a3f     HI_VAR2     HI_VAR2   test
# 16  7aefc672-316d-42c4-bcb4-225d68238a38     HI_VAR3     HI_VAR3   test
# 17  64979c54-d7fd-4b9a-bcf0-e826e622926b       LD_HL       LD_HL   test
# 18  532f3dae-ee06-4e11-b154-5e6f3cd8e84a       LD_BK       LD_BK   test
# 19  8fbbef5d-0636-4795-86d2-7d2b4e697418    LD_BK-WN    LD_BK-WN   test
# 20  1730bc53-171c-4073-a6e0-aba64ee1644b       LD_AB       LD_AB   test
# 21  80ac25b9-a3de-4530-95b5-1560571f3813       LD_LP       LD_LP   test
# 22  efd0cc2c-ae64-4156-8c87-7345ac7a2207       LD_RO       LD_RO   test
# 23  08875281-cc6e-4937-8604-999b24bfe5a7       LD_WN       LD_WN   test
#
#    RunTitle KeywordFile  SamplingWt Variant Version        RV      Groups  \
# 0     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 1     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 2     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 3     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 4     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 5     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 6     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 7     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 8     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 9     Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 10    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 11    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 12    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 13    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 14    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 15    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 16    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 17    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 18    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 19    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 20    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 21    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 22    Run 1        run2         1.0      SN    3261  20201010  All_Stands
# 23    Run 1        run2         1.0      SN    3261  20201010  All_Stands
#
#             RunDateTime
# 0   2022-01-18-13:01:40
# 1   2022-01-18-13:01:41
# 2   2022-01-18-13:01:41
# 3   2022-01-18-13:01:41
# 4   2022-01-18-13:01:41
# 5   2022-01-18-13:01:41
# 6   2022-01-18-13:01:42
# 7   2022-01-18-13:01:42
# 8   2022-01-18-13:01:42
# 9   2022-01-18-13:01:42
# 10  2022-01-18-13:01:42
# 11  2022-01-18-13:01:42
# 12  2022-01-18-13:01:43
# 13  2022-01-18-13:01:43
# 14  2022-01-18-13:01:43
# 15  2022-01-18-13:01:44
# 16  2022-01-18-13:01:44
# 17  2022-01-18-13:01:44
# 18  2022-01-18-13:01:44
# 19  2022-01-18-13:01:45
# 20  2022-01-18-13:01:45
# 21  2022-01-18-13:01:45
# 22  2022-01-18-13:01:45
# 23  2022-01-18-13:01:45

# %%
for case in carbon['StandID'].unique():
    tdf = carbon[carbon['StandID'] == case]
    csum = tdf['Aboveground_Total_Live'] + tdf['Belowground_Live'] 
    plt.plot(tdf['Year'],csum.cumsum(), label = 'sum')
    plt.plot(tdf['Year'],tdf['Aboveground_Total_Live'].cumsum(), label = 'AGB')
    plt.plot(tdf['Year'],tdf['Belowground_Live'].cumsum(), label = 'BGB')
    plt.title(case)
    plt.legend()
    print(tdf['StandID'].unique()[0])
    plt.show()
# Out:
# Base_HL
# Base_BK
# Base_BK-WN
# Base_AB
# Base_LP
# Base_RO
# Base_WN
# HD_HL
# HD_BK
# HD_BK-WN
# HD_AB
# HD_LP
# HD_RO
# HD_WN
# HI_VAR1
# HI_VAR2
# HI_VAR3
# LD_HL
# LD_BK
# LD_BK-WN
# LD_AB
# LD_LP
# LD_RO
# LD_WN
